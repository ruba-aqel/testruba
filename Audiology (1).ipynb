# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Ruba Aqel**
#
# A Bioinformatician

# %% [markdown]
# *I am interested in data science because it will help me provide better healthcare insights. Also it will help me change my career path*

# %% [markdown]
# ### The following code tests a square function

# %%
def square(x):
    return x*x

square(2)
# Out:
# 4

# %% [markdown]
# [I'm a hyperlink for coursera website](https://www.coursera.com)
#
# 1. This is a numbered list which includes
# 2. A hyperlink
# 3. A numbered list
# 4. A table
#
#
# | This       | is a       | Table  |
# | ---------- |:----------:| ------:|
# | First row  | One        | 1      |
# | second row | Two        | 2      |
# | third row  | Three      | 3      |
